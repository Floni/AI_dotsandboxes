# %%
from dotsandboxesplayer import *
from dotsandboxesgame import *
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
g = Game((8, 10), dqn_player, Player)
# Out:
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/python/ops/clip_ops.py:113: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Summary name Last 100 avg. reward is illegal; using Last_100_avg._reward instead.
# INFO:tensorflow:Restoring parameters from model/weights.ckpt-75252
# checkpoint restored

# %%
g.train(50000)
# Out:
# Step:  0  last 100 avg. loss:  0.0 time:  12.329822063446045
# game:  0 last 1000 games:
# scores: 	 1 	 2
# wins: 		 0  ( 0.0 %)	 1  ( 0.1 %)
# cheats: 	 0  ( 0.0 %)	 0  ( 0.0 %)
# draws:  0  ( 0.0 %)
# -----------------------------------------------
# saved in: model/weights3x1.ckpt-0
# Step:  5086  last 100 avg. loss:  1806.1103450317382 time:  11.535603046417236
# game:  1000 last 1000 games:
# scores: 	 1652 	 1348
# wins: 		 544  ( 54.4 %)	 456  ( 45.6 %)
# cheats: 	 0  ( 0.0 %)	 0  ( 0.0 %)
# draws:  0  ( 0.0 %)
# -----------------------------------------------
# saved in: model/weights3x1.ckpt-5086
# Step:  10355  last 100 avg. loss:  1596.94013772583 time:  11.905636548995972
# game:  2000 last 1000 games:
# scores: 	 1837 	 1163
# wins: 		 632  ( 63.2 %)	 368  ( 36.8 %)
# cheats: 	 0  ( 0.0 %)	 0  ( 0.0 %)
# draws:  0  ( 0.0 %)
# -----------------------------------------------
# saved in: model/weights3x1.ckpt-10355
# ...

# %%
g.eval(100)

# %%
g.play_game()
# Out:
# player:  1
# + + + + + +
#           |
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  2
# + + + + + +
#           |
# + + + + + +
#         I
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  1
# + + + + + +
# |         |
# + + + + + +
#         I
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  2
# +=+ + + + +
# |         |
# + + + + + +
#         I
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  1
# +=+ + + + +
# |         |
# + + + + + +
#         I |
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  2
# +=+ + + + +
# |         |
# + + + + + +
#         I |
# + + + + + +
#
# + + + + + +
#
# + + + + + +
#           I
# + + + + + +
#
#
# score: [0, 0] ended: False
# player:  1
# ...

# %%
g.players[0].epsilon = 0.1

# %%
g.players[1] = QPlayer(g.size)

# %%
p2 = g.players[1]
g.players[1] = Player(g.size)
g.eval(1000)
g.players[1] = p2
# Out:
# scores: 	 2872 	 1128
# wins: 		 688  ( 68.8 %)	 65  ( 6.5 %)
# cheats: 	 0  ( 0.0 %)	 0  ( 0.0 %)
# draws:  247  ( 24.7 %)
# -----------------------------------------------

# %%
g.players[1] = Player(g.size)
